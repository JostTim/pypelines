# %%
from pypelines import Session
from pypelines.examples import example_pipeline
import logging, sys

logger = logging.getLogger()
logger.addHandler(logging.StreamHandler(sys.stdout))
logger.setLevel("DEBUG")

# %%
session = Session(subject="wm32",date="2023-08-25",number=1,path=r"C:\test", auto_path = True)
session
# Out:
# subject                           wm32
# date                        2023-08-25
# number                               1
# path       C:\test\wm32\2023-08-25\001
# alias              wm32_2023-08-25_001
# Name: wm32_2023-08-25_001, dtype: object

# %%
example_pipeline.treated_videos.requirement_stack()
# Out:
# []

# %%
example_pipeline.treated_videos.generate(session, "JPEG")
# Out:
# Searching at folder : C:\test\wm32\2023-08-25\001\preprocessing_saves with pattern='example\\.treated_videos(?:\\.(?P<step_name>(?:compress))(?:\\.(?P<version>[^\\.]*))?)?\\.pickle'
# Found files : ['example.treated_videos.compress.pickle']
# Matched a single file : C:\test\wm32\2023-08-25\001\preprocessing_saves\example.treated_videos.compress.pickle with self.disk_step='compress' self.disk_version=None
# Found data. Trying to load it in generation context
# Current disk file status : self.current_disk_file = 'C:\\test\\wm32\\2023-08-25\\001\\preprocessing_saves\\example.treated_videos.compress.pickle'
# Loaded treated_videos file. Processing has been skipped
# {'pixels': [1, 2, 5, 7, 18, 8, 9, 8, 21],
#  'video_codec': 'JPEG',
#  'compression_rate': 0.5}

# %%
example_pipeline.local_features.template_matches.generate(session, "JPEG", run_requirements = True, refresh = True, extra = "C1")
# Out:
# Searching at folder : C:\test\wm32\2023-08-25\001\preprocessing_saves with pattern='example\\.local_features(?:\\.(?P<step_name>(?:template_matches)|(?:templates_new_locations))(?:\\.(?P<version>[^\\.]*))?)?\\.C1\\.pickle'
# Found files : []
# `refresh` was set to True, ignoring the state of disk files and running the function.
# Running requirement background_features.scale_spaces
# Searching at folder : C:\test\wm32\2023-08-25\001\preprocessing_saves with pattern='example\\.background_features(?:\\.(?P<step_name>(?:blobs)|(?:detect_buildings)|(?:enhanced_background)|(?:scale_spaces))(?:\\.(?P<version>[^\\.]*))?)?\\.pickle'
# Found files : ['example.background_features.scale_spaces.3.pickle']
# Matched a single file : C:\test\wm32\2023-08-25\001\preprocessing_saves\example.background_features.scale_spaces.3.pickle with self.disk_step='scale_spaces' self.disk_version='3'
# File exists for background_features. Loading and processing have been skipped
# ...

# %%
# Out:
# <local_features.template_matches StepObject>

# %%
def filter_stack(pipe,stack):
    return [req for req in stack if req.pipe_name == pipe.pipe_name]

# %%
StepLevel(example_pipeline.local_features.templates_new_locations).resolve_level()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\tjostmou\Documents\Python\__packages__\Pypelines\pypelines\feature_test.ipynb Cell 7 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/tjostmou/Documents/Python/__packages__/Pypelines/pypelines/feature_test.ipynb#X50sZmlsZQ%3D%3D?line=0'>1</a> StepLevel(example_pipeline.local_features.templates_new_locations).resolve_level()
#
# NameError: name 'StepLevel' is not defined

# %%
pipe = example_pipeline.local_features
steps = list(pipe.steps.values())
for step in steps :
    stack = step.requirement_stack()
    print(filter_stack(pipe,stack))
# Out:
# []
# [<local_features.template_matches StepObject>]

# %%
example_pipeline.modified_videos.draw_godzilla(session)
# Out:
# modified_videos.draw_godzilla
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\tjostmou\Documents\Python\__packages__\Pypelines\pypelines\feature_test.ipynb Cell 6 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/tjostmou/Documents/Python/__packages__/Pypelines/pypelines/feature_test.ipynb#X42sZmlsZQ%3D%3D?line=0'>1</a> example_pipeline.modified_videos.draw_godzilla(session)
#
# File c:\users\tjostmou\documents\python\__packages__\pypelines\pypelines\steps.py:73, in BaseStep.__call__(self, *args, **kwargs)
#      72 def __call__(self, *args, **kwargs):
# ---> 73     return self.worker(*args, **kwargs)
#
# File c:\users\tjostmou\documents\python\__packages__\pypelines\pypelines\examples.py:29, in modified_videos.draw_godzilla(self, session, roar, extra)
# ...

# %%
example_pipeline.draw_graph(x_spacing = 20, layout = "tree")
# Out:
# matplotlib data path: c:\Users\tjostmou\anaconda3\envs\Inflow\Lib\site-packages\matplotlib\mpl-data
# CONFIGDIR=C:\Users\tjostmou\.matplotlib
# interactive is False
# platform is win32
# CACHEDIR=C:\Users\tjostmou\.matplotlib
# Using fontManager instance from C:\Users\tjostmou\.matplotlib\fontlist-v330.json
# Loaded backend module://matplotlib_inline.backend_inline version unknown.
# Loaded backend module://matplotlib_inline.backend_inline version unknown.
# findfont: Matching sans\-serif:style=normal:variant=normal:weight=normal:stretch=normal:size=10.0.
# findfont: score(FontEntry(fname='c:\\Users\\tjostmou\\anaconda3\\envs\\Inflow\\Lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\DejaVuSansMono-Bold.ttf', name='DejaVu Sans Mono', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# ...

# %%
example_pipeline.modified_videos.steps.values()
# Out:
# dict_values([<modified_videos.draw_godzilla StepObject>, <modified_videos.draw_templates StepObject>])

# %%
example_pipeline.modified_videos.draw_godzilla.get_level(selfish=True)
# Out:
# 1

# %%
example_pipeline.modified_videos.draw_godzilla.requirement_stack()
# Out:
# [<treated_videos.compress StepObject>,
#  <background_features.scale_spaces StepObject>,
#  <local_features.template_matches StepObject>,
#  <background_features.enhanced_background StepObject>,
#  <background_features.blobs StepObject>,
#  <local_features.templates_new_locations StepObject>,
#  <modified_videos.draw_templates StepObject>,
#  <background_features.detect_buildings StepObject>]

# %%
example_pipeline.background_features.get_steps_levels()
# Out:
# {<background_features.blobs StepObject>: 1,
#  <background_features.detect_buildings StepObject>: 0,
#  <background_features.enhanced_background StepObject>: 0,
#  <background_features.scale_spaces StepObject>: 0}

# %%
pipe_indices = { pipe.pipe : index for index, pipe in enumerate(example_pipeline.pipes.values())}
pipe_indices
# Out:
# {<PicklePipe.treated_videos PipeObject>: 0,
#  <PicklePipe.modified_videos PipeObject>: 1,
#  <PicklePipe.background_features PipeObject>: 2,
#  <PicklePipe.local_features PipeObject>: 3}
